# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyaa2015/REP-1/blob/main/linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets

# %%
diabetes=datasets.load_diabetes()

# %%
X=diabetes.data

# %%
Y=diabetes.target

# %%
X.shape , Y.shape
# Out:
# ((442, 10), (442,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train.shape , Y_train.shape
# Out:
# ((353, 10), (353,))

# %%
X_test.shape , Y_test.shape
# Out:
# ((89, 10), (89,))

# %%
from sklearn import linear_model, metrics
from sklearn.metrics import accuracy_score

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = reg.predict(X_test)

# %%
print('Coefficients: ', reg.coef_)
print('intercept ', reg.intercept_)
# Out:
# Coefficients:  [  24.54105712 -217.448369    500.4748571   360.56467435 -664.22647904
#   383.73218063  -16.78226179   75.67498012  718.78894431   -1.31166202]
# intercept  150.66787157105077

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
print('mean square error: ',mean_squared_error(Y_test, Y_pred))
# Out:
# mean square error:  2959.0067410237625

# %%
print('r2-score: ',r2_score(Y_test, Y_pred))
# Out:
# r2-score:  0.5607437390993311

# %%
import matplotlib.pyplot as plt

plt.scatter(Y_test, Y_pred, alpha=0.9)
plt.xlabel("Actual Diabetes Progression")
plt.ylabel("Predicted Diabetes Progression")
plt.title("Actual vs Predicted Values")
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--')
plt.show()

# %%
ridg=linear_model.Ridge(alpha=1.0)
ridg.fit(X_train, Y_train)
Y_pred = ridg.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print('mean square error: ',mean_squared_error(Y_test, Y_pred))
print('r2-score: ',r2_score(Y_test, Y_pred))
plt.scatter(Y_test, Y_pred, alpha=0.9)
plt.xlabel("Actual Diabetes Progression")
plt.ylabel("Predicted Diabetes Progression")
plt.title("Actual vs Predicted Values")
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--')
plt.show()
# Out:
# mean square error:  3556.4483499417056
# r2-score:  0.4720552060177946

# %%
lass=linear_model.Lasso(alpha=0.1)
lass.fit(X_train, Y_train)
Y_pred = lass.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print('mean square error: ',mean_squared_error(Y_test, Y_pred))
print('r2-score: ',r2_score(Y_test, Y_pred))
plt.scatter(Y_test, Y_pred, alpha=0.9)
plt.xlabel("Actual Diabetes Progression")
plt.ylabel("Predicted Diabetes Progression")
plt.title("Actual vs Predicted Values")
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--')
plt.show()
# Out:
# mean square error:  3001.3649371435745
# r2-score:  0.5544557835539348
